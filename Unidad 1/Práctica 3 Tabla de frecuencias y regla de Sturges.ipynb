# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid-eortiz/TrabajosProbabilidad/blob/main/Unidad%201/Pr%C3%A1ctica%203%20Tabla%20de%20frecuencias%20y%20regla%20de%20Sturges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
# ## Unidad 1
# ### Docente: Jose Gabriel Rodriguez Rivas
# ### Alumno: Zaid Emilio Ortiz Amparan
# ### **Práctica 3 Tabla de frecuencias y regla de Sturges**

# %%
import random
edades = []
for i in range (100) :
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [64, 28, 19, 24, 20, 33, 50, 48, 44, 70, 44, 46, 69, 20, 41, 61, 46, 69, 26, 22, 21, 38, 39, 46, 67, 53, 24, 20, 44, 33, 29, 25, 20, 60, 37, 68, 43, 62, 42, 51, 69, 51, 35, 34, 41, 21, 25, 58, 35, 63, 56, 53, 28, 58, 21, 35, 48, 64, 65, 38, 49, 58, 33, 67, 33, 64, 64, 70, 56, 34, 33, 40, 39, 38, 23, 51, 42, 36, 32, 45, 48, 22, 38, 21, 32, 64, 68, 70, 25, 38, 52, 63, 40, 46, 62, 38, 53, 48, 35, 55]

# %%
import pandas as pd
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    64
# 1    28
# 2    19
# 3    24
# 4    20

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribucion de Frecuencias")
print(tabla_frecuencias)
# Out:
# Tabla de Distribucion de Frecuencias
#     Edad  Frecuencia
# 29    19           1
# 3     20           4
# 6     21           4
# 27    22           2
# 38    23           1
# 18    24           2
# 8     25           3
# 32    26           1
# 15    28           2
# 34    29           1
# 16    32           2
# 2     33           5
# 23    34           2
# 5     35           4
# 40    36           1
# 31    37           1
# 0     38           6
# 19    39           2
# 17    40           2
# 26    41           2
# 24    42           2
# 36    43           1
# 11    44           3
# 41    45           1
# 4     46           4
# 7     48           4
# 39    49           1
# 30    50           1
# 12    51           3
# 42    52           1
# 14    53           3
# 43    55           1
# 28    56           2
# 13    58           3
# 35    60           1
# 33    61           1
# 20    62           2
# 22    63           2
# 1     64           5
# 37    65           1
# 25    67           2
# 21    68           2
# 10    69           3
# 9     70           3

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia'] / 100
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec relativa
# 29    19           1           0.01
# 3     20           4           0.04
# 6     21           4           0.04
# 27    22           2           0.02
# 38    23           1           0.01
# 18    24           2           0.02
# 8     25           3           0.03
# 32    26           1           0.01
# 15    28           2           0.02
# 34    29           1           0.01
# 16    32           2           0.02
# 2     33           5           0.05
# 23    34           2           0.02
# 5     35           4           0.04
# 40    36           1           0.01
# 31    37           1           0.01
# 0     38           6           0.06
# 19    39           2           0.02
# 17    40           2           0.02
# 26    41           2           0.02
# 24    42           2           0.02
# 36    43           1           0.01
# 11    44           3           0.03
# 41    45           1           0.01
# 4     46           4           0.04
# 7     48           4           0.04
# 39    49           1           0.01
# 30    50           1           0.01
# 12    51           3           0.03
# 42    52           1           0.01
# 14    53           3           0.03
# 43    55           1           0.01
# 28    56           2           0.02
# 13    58           3           0.03
# 35    60           1           0.01
# 33    61           1           0.01
# 20    62           2           0.02
# 22    63           2           0.02
# 1     64           5           0.05
# 37    65           1           0.01
# 25    67           2           0.02
# 21    68           2           0.02
# 10    69           3           0.03
# 9     70           3           0.03

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcentual
# 29    19           1            1.0              1.0
# 3     20           4            4.0              4.0
# 6     21           4            4.0              4.0
# 27    22           2            2.0              2.0
# 38    23           1            1.0              1.0
# 18    24           2            2.0              2.0
# 8     25           3            3.0              3.0
# 32    26           1            1.0              1.0
# 15    28           2            2.0              2.0
# 34    29           1            1.0              1.0
# 16    32           2            2.0              2.0
# 2     33           5            5.0              5.0
# 23    34           2            2.0              2.0
# 5     35           4            4.0              4.0
# 40    36           1            1.0              1.0
# 31    37           1            1.0              1.0
# 0     38           6            6.0              6.0
# 19    39           2            2.0              2.0
# 17    40           2            2.0              2.0
# 26    41           2            2.0              2.0
# 24    42           2            2.0              2.0
# 36    43           1            1.0              1.0
# 11    44           3            3.0              3.0
# 41    45           1            1.0              1.0
# 4     46           4            4.0              4.0
# 7     48           4            4.0              4.0
# 39    49           1            1.0              1.0
# 30    50           1            1.0              1.0
# 12    51           3            3.0              3.0
# 42    52           1            1.0              1.0
# 14    53           3            3.0              3.0
# 43    55           1            1.0              1.0
# 28    56           2            2.0              2.0
# 13    58           3            3.0              3.0
# 35    60           1            1.0              1.0
# 33    61           1            1.0              1.0
# 20    62           2            2.0              2.0
# 22    63           2            2.0              2.0
# 1     64           5            5.0              5.0
# 37    65           1            1.0              1.0
# 25    67           2            2.0              2.0
# 21    68           2            2.0              2.0
# 10    69           3            3.0              3.0
# 9     70           3            3.0              3.0

# %%
tabla_frecuencias['Frec Acumulada '] = tabla_frecuencias['Frecuencia']. cumsum()
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcentual  Frec Acumulada
# 29    19           1            1.0              1.0                1
# 3     20           4            4.0              4.0                5
# 6     21           4            4.0              4.0                9
# 27    22           2            2.0              2.0               11
# 38    23           1            1.0              1.0               12
# 18    24           2            2.0              2.0               14
# 8     25           3            3.0              3.0               17
# 32    26           1            1.0              1.0               18
# 15    28           2            2.0              2.0               20
# 34    29           1            1.0              1.0               21
# 16    32           2            2.0              2.0               23
# 2     33           5            5.0              5.0               28
# 23    34           2            2.0              2.0               30
# 5     35           4            4.0              4.0               34
# 40    36           1            1.0              1.0               35
# 31    37           1            1.0              1.0               36
# 0     38           6            6.0              6.0               42
# 19    39           2            2.0              2.0               44
# 17    40           2            2.0              2.0               46
# 26    41           2            2.0              2.0               48
# 24    42           2            2.0              2.0               50
# 36    43           1            1.0              1.0               51
# 11    44           3            3.0              3.0               54
# 41    45           1            1.0              1.0               55
# 4     46           4            4.0              4.0               59
# 7     48           4            4.0              4.0               63
# 39    49           1            1.0              1.0               64
# 30    50           1            1.0              1.0               65
# 12    51           3            3.0              3.0               68
# 42    52           1            1.0              1.0               69
# 14    53           3            3.0              3.0               72
# 43    55           1            1.0              1.0               73
# 28    56           2            2.0              2.0               75
# 13    58           3            3.0              3.0               78
# 35    60           1            1.0              1.0               79
# 33    61           1            1.0              1.0               80
# 20    62           2            2.0              2.0               82
# 22    63           2            2.0              2.0               84
# 1     64           5            5.0              5.0               89
# 37    65           1            1.0              1.0               90
# 25    67           2            2.0              2.0               92
# 21    68           2            2.0              2.0               94
# 10    69           3            3.0              3.0               97
# 9     70           3            3.0              3.0              100

# %%
import math
print(edades)
# Out:
# [64, 28, 19, 24, 20, 33, 50, 48, 44, 70, 44, 46, 69, 20, 41, 61, 46, 69, 26, 22, 21, 38, 39, 46, 67, 53, 24, 20, 44, 33, 29, 25, 20, 60, 37, 68, 43, 62, 42, 51, 69, 51, 35, 34, 41, 21, 25, 58, 35, 63, 56, 53, 28, 58, 21, 35, 48, 64, 65, 38, 49, 58, 33, 67, 33, 64, 64, 70, 56, 34, 33, 40, 39, 38, 23, 51, 42, 36, 32, 45, 48, 22, 38, 21, 32, 64, 68, 70, 25, 38, 52, 63, 40, 46, 62, 38, 53, 48, 35, 55]

# %%
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     64
# 1     28
# 2     19
# 3     24
# 4     20
# ..   ...
# 95    38
# 96    53
# 97    48
# 98    35
# 99    55
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n = ", n , "\nNumero de intervalos", k)
# Out:
# Valor de n =  100
# Numero de intervalos 7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (18.948, 26.286]    18
# 1  (33.571, 40.857]    18
# 2    (62.714, 70.0]    18
# 3  (40.857, 48.143]    17
# 4  (26.286, 33.571]    10
# 5  (48.143, 55.429]    10
# 6  (55.429, 62.714]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (18.948, 26.286]    18
# 4  (26.286, 33.571]    10
# 1  (33.571, 40.857]    18
# 3  (40.857, 48.143]    17
# 5  (48.143, 55.429]    10
# 6  (55.429, 62.714]     9
# 2    (62.714, 70.0]    18

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (18.948, 26.286]    18      0.18       18.0       18         0.18
# 4  (26.286, 33.571]    10      0.10       10.0       28         0.28
# 1  (33.571, 40.857]    18      0.18       18.0       46         0.46
# 3  (40.857, 48.143]    17      0.17       17.0       63         0.63
# 5  (48.143, 55.429]    10      0.10       10.0       73         0.73
# 6  (55.429, 62.714]     9      0.09        9.0       82         0.82
# 2    (62.714, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 0          18.0
# 4          28.0
# 1          46.0
# 3          63.0
# 5          73.0
# 6          82.0
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de mathplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de mathplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
