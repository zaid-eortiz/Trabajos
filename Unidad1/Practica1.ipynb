# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid-eortiz/Trabajos/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# # **Unidad 1**
# ## Pactica 1: **Estadistica Descriptiva e Histogramas**
# Docente : Jose Gabriel Rodriguez Rivas
#
# Alumno: Zaid Emilio Ortiz Amparan

# %%
from statistics import *

# %%
# Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa =[70,70,65,90,100,95,45,80,73,20,100,96]
print (grupoa)
type (grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
#sacar la media de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
from statistics import mean
#Utilizar la funcion mean que esta en la libreria statistics para sacar
#promedio

promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
from statistics import median
#Determinar el valor de la mediana con la funcion median

mediana = median(grupoa)
print(mediana)
# Out:
# 76.5
